# %%
import pandas as pd
from sqlalchemy import create_engine


"importing done"
# Out:
# 'importing done'

# %%
# Database connection settings
DATABASE_CONNECTION_STRING = "mssql+pyodbc://Linxus_K2:K2s$072021.*@enaexsouthafrica.database.windows.net/ENAEX_FIN_PRD?driver=ODBC+Driver+17+for+SQL+Server"

# %%
# Excel file path
# EXCEL_FILE_PATH = "49_DOTACTION STAGING.xlsx"

csv_file = "49_DOTACTION STAGING.csv"
from datetime import datetime

df = pd.read_csv(csv_file)

# Display the DataFrame's columns
print("DataFrame Columns:", df.columns)

# Define the columns to be parsed as datetime
parse_dates = ['Birth Date', 'Joined Group', 'Seperation Date']

# Parse specified columns as datetime with the correct format
df[parse_dates] = df[parse_dates].apply(pd.to_datetime, format='%d-%m-%Y %H:%M')


# Load data from Excel into a Pandas DataFrame
# df = pd.read_excel(EXCEL_FILE_PATH)
# df = pd.read_csv(csv_file, dtype=schema)
df
# Out:
# DataFrame Columns: Index(['Personnel Number', 'Employement Status', 'Last Name', 'Initials',
#        'Known As', 'Title', 'Ethnic Origin', 'Gender', 'ID Number',
#        'Nationality', ' Payr area Text ', 'Employee Group', 'Employe subgroup',
#        'Company Code', 'Company Text', 'Personal area', 'PA Text',
#        'Personnel subarea', 'PSA Text', 'Organizational unit', 'Org Short',
#        'Org unit Text', 'Cost Centre', 'Cost Centre Text', 'Position',
#        'Position JCC', 'Position Name', 'Job Key', 'Job JCC', 'Job Name',
#        'Business Unit', 'BU Text', 'Role Category', 'Role Cat Text',
#        'Work Centre', ' Location Text ', 'Birth Date', 'Unnamed: 37',
#        'Age in Years', 'Joined Group', 'Seperation Date', 'Seperation Reason',
#        'Service Years', 'EE no of Superior', 'Name o Superior', 'E-mail',
#        ' Overtime Units ', 'Lve'],
#       dtype='object')
#       Personnel Number Employement Status  Last Name Initials  \
# ...

# %%
df.columns
# Out:
# Index(['Personnel Number', 'Employement Status', 'Last Name', 'Initials',
#        'Known As', 'Title', 'Ethnic Origin', 'Gender', 'ID Number',
#        'Nationality', ' Payr area Text ', 'Employee Group', 'Employe subgroup',
#        'Company Code', 'Company Text', 'Personal area', 'PA Text',
#        'Personnel subarea', 'PSA Text', 'Organizational unit', 'Org Short',
#        'Org unit Text', 'Cost Centre', 'Cost Centre Text', 'Position',
#        'Position JCC', 'Position Name', 'Job Key', 'Job JCC', 'Job Name',
#        'Business Unit', 'BU Text', 'Role Category', 'Role Cat Text',
#        'Work Centre', ' Location Text ', 'Birth Date', 'Unnamed: 37',
#        'Age in Years', 'Joined Group', 'Seperation Date', 'Seperation Reason',
#        'Service Years', 'EE no of Superior', 'Name o Superior', 'E-mail',
#        ' Overtime Units ', 'Lve'],
#       dtype='object')

# %%
df= df[['Personnel Number', 'Employement Status', 'Last Name', 'Known As','Gender',
        'ID Number','Nationality', 'Employe subgroup', 'Personal area', 'PA Text',
        'Cost Centre', 'Cost Centre Text', 'Position','Position Name',
        'Role Category', 'Role Cat Text','Birth Date',  'Joined Group', 'Seperation Date']]
df
# Out:
#       Personnel Number Employement Status  Last Name          Known As Gender  \
# 0            1015968.0             Active  Mathenjwa   Mguneni Comfort      M
# 1              30034.0             Active    Van Wyk    Michael Daniel      M
# 2            1031617.0             Active   Kernahan             Neil       M
# 3              60123.0             Active     Fourie   Petrus Johannes      M
# 4             501144.0             Active    Schulze      John Charles      M
# ...                ...                ...        ...               ...    ...
# 1217        99000639.0                New    Moodley          Pravani       F
# 1218        99000640.0                New    Mohamed         Zandiswa       F
# 1219           12457.0         Terminated     Mdluli  Mangese Johannes      M
# 1220        99000030.0             Active     Maloka     Thabo Rampudi      M
# 1221               NaN                NaN        NaN               NaN    NaN
#
# ...

# %%
new_col = {'Personnel Number': "Employee Nr",'Employement Status': "Employment status",'Employe subgroup': "Employee subgroup",'Personal area': "Personnel area",'Cost Centre Text': "Cost Center Name",'Position Name': "Position_TEXT", 'Role Cat Text': "Role Category Code",'Birth Date':"birdate", 'Seperation Date':"Separation"}

df.rename(columns=new_col, inplace=True)

df

# import numpy as np
# from datetime import datetime
# # Define the schema
# schema = {
#     'Employee Nr': str,
#     'Employment status': str,
#     'Last Name': object,
#     'Known As': object,
#     'Gender': object,
#     'ID Number': object,
#     'Nationality': object,
#     'Employee subgroup': object,
#     'Personnel area': object,
#     'PA Text': object,
#     'Cost Centre': object,
#     'Cost Center Name': object,
#     'Position': object,
#     'Position_TEXT': object,
#     'Role Category': object,
#     'Role Category Code': object,
#     'birdate': 'datetime64[ns]',
#     'Joined Group': 'datetime64[ns]',
#     'Separation': 'datetime64[ns]'
# }

# # Set the schema for the DataFrame
# df = df.astype(schema)

# df
# Out:
# C:\Users\ajay\AppData\Local\Temp\ipykernel_6772\1863515711.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=new_col, inplace=True)
#       Employee Nr Employment status  Last Name          Known As Gender  \
# 0       1015968.0            Active  Mathenjwa   Mguneni Comfort      M
# 1         30034.0            Active    Van Wyk    Michael Daniel      M
# 2       1031617.0            Active   Kernahan             Neil       M
# 3         60123.0            Active     Fourie   Petrus Johannes      M
# 4        501144.0            Active    Schulze      John Charles      M
# ...           ...               ...        ...               ...    ...
# 1217   99000639.0               New    Moodley          Pravani       F
# ...

# %%
df.columns
# Out:
# Index(['Employee Nr', 'Employment status', 'Last Name', 'Known As', 'Gender',
#        'ID Number', 'Nationality', 'Employee subgroup', 'Personnel area',
#        'PA Text', 'Cost Centre', 'Cost Center Name', 'Position',
#        'Position_TEXT', 'Role Category', 'Role Category Code', 'birdate',
#        'Joined Group', 'Separation'],
#       dtype='object')

# %%
# Table name in SQL Server
TABLE_NAME = "49_DOTACTION_STAGING"

# Connect to the SQL Server database
engine = create_engine(DATABASE_CONNECTION_STRING)

# Insert data into the SQL Server table
df.to_sql(name=TABLE_NAME, con=engine, if_exists='replace', index=False)

print("Data loaded successfully into SQL Server table:", TABLE_NAME)
# Out:
# Data loaded successfully into SQL Server table: 49_DOTACTION_STAGING
